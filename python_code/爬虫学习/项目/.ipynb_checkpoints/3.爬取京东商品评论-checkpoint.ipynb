# %% [markdown]
# 首先分析一下京东商品评论是如何加载的
# 我们以一款华为手机为例子
# https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv516&productId=6946635&score=0&sortType=5&page=1&pageSize=10&isShadowSku=0&rid=0&fold=1
#
# https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv516&productId=6946635&score=0&sortType=5&page=2&pageSize=10&isShadowSku=0&rid=0&fold=1
#
# https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv516&productId=6946635&score=0&sortType=5&page=3&pageSize=10&isShadowSku=0&rid=0&fold=1

# %% [markdown]
# 分析以上的请求，得到规律
# base_url = 'https://sclub.jd.com/comment/productPageComments.action?'
# params = {
#     'callback':'fetchJSON comment98vv516',
#     'productId':'6946635',
#     'score':'0',
#     'sortType':'5',
#     'page':page,
#     'pageSize':'10',
#     'isShadowSku':'0',
#     'rid':'0',
#     'fold':'1'
# }

# %%
import requests
from urllib.parse import urlencode

base_url = 'https://sclub.jd.com/comment/productPageComments.action?'
page = 5
params = {
    'callback':'fetchJSON comment98vv516',
    'productId':'6946635',
    'score':'0',
    'sortType':'5',
    'page':page,
    'pageSize':'10',
    'isShadowSku':'0',
    'rid':'0',
    'fold':'1'
}

url = base_url + urlencode(params)
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
# 看一下文本内容
print(response.text)
# Out:
# fetchJSON+comment98vv516({"productAttr":null,"productCommentSummary":{"goodRateShow":99,"poorRateShow":0,"poorCountStr":"100+","averageScore":5,"generalCountStr":"100+","oneYear":0,"showCount":3800,"showCountStr":"3800+","goodCount":61000,"generalRate":0.99,"generalCount":100,"skuId":6946635,"goodCountStr":"6.1万+","poorRate":0.0020,"afterCount":300,"goodRateStyle":148,"poorCount":100,"skuIds":null,"poorRateStyle":0,"generalRateStyle":2,"commentCountStr":"6.2万+","commentCount":62000,"productId":6946635,"afterCountStr":"300+","defaultGoodCount":46000,"goodRate":0.99,"generalRateShow":1,"defaultGoodCountStr":"4.6万+"},"hotCommentTagStatistics":[{"id":"9255a9406d7c6996","name":"眼前一亮","rid":"9255a9406d7c6996","count":122,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=9255a9406d7c6996^^pid=20001^^sku=6946635^^sversion=1000^^token=4e95d4dbae38e31a"},{"id":"75939b54ad8c3c8c","name":"外观美美哒","rid":"75939b54ad8c3c8c","count":44,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=75939b54ad8c3c8c^^pid=20001^^sku=6946635^^sversion=1000^^token=8aa0129361d128fe"},{"id":"dfb9ca5586caf544","name":"国产粉丝党","rid":"dfb9ca5586caf544","count":28,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=dfb9ca5586caf544^^pid=20001^^sku=6946635^^sversion=1000^^token=405e80c8e9711f56"},{"id":"138066a0d614e743","name":"全能产品","rid":"138066a0d614e743","count":24,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=138066a0d614e743^^pid=20001^^sku=6946635^^sversion=1000^^token=aa7671a914c2336b"},{"id":"3607557658a3dbc1","name":"快快快","rid":"3607557658a3dbc1","count":18,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=3607557658a3dbc1^^pid=20001^^sku=6946635^^sversion=1000^^token=8c8d313ea2172eec"},{"id":"54830c7b549f9402","name":"简直完美","rid":"54830c7b549f9402","count":9,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=54830c7b549f9402^^pid=20001^^sku=6946635^^sversion=1000^^token=becfef9dbd886532"},{"id":"0bacd2244270003d","name":"超高性价比","rid":"0bacd2244270003d","count":7,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=0bacd2244270003d^^pid=20001^^sku=6946635^^sversion=1000^^token=53de92de723c1f88"},{"id":"5c595753b7b31868","name":"堪比单反","rid":"5c595753b7b31868","count":6,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=5c595753b7b31868^^pid=20001^^sku=6946635^^sversion=1000^^token=1cc0828ec0104282"},{"id":"6f45fc31271ea545","name":"而且便宜","rid":"6f45fc31271ea545","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=6f45fc31271ea545^^pid=20001^^sku=6946635^^sversion=1000^^token=eb43301eb406e741"},{"id":"22d498d28602b79f","name":"续航能力强","rid":"22d498d28602b79f","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=22d498d28602b79f^^pid=20001^^sku=6946635^^sversion=1000^^token=1aca49ed749d5be2"},{"id":"bf87168fb66cf160","name":"非常耐用","rid":"bf87168fb66cf160","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=bf87168fb66cf160^^pid=20001^^sku=6946635^^sversion=1000^^token=e9001b2c5d9dd170"},{"id":"8409ae56b10f635b","name":"刚好适合","rid":"8409ae56b10f635b","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=8409ae56b10f635b^^pid=20001^^sku=6946635^^sversion=1000^^token=0406d93dd7a7c37d"},{"id":"e8c1530719ca2fc6","name":"电池续航能力强","rid":"e8c1530719ca2fc6","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=e8c1530719ca2fc6^^pid=20001^^sku=6946635^^sversion=1000^^token=f0bee2225ad702ab"}],"jwotestProduct":"99","maxPage":100,"score":0,"soType":5,"imageListCount":500,"vTagStatistics":null,"comments":[{"id":11441149474,"topped":0,"guid":"be7f1d4a-8d68-432c-80c1-dd037d203c2c","content":"京东买了无数次东西，头一次打算好好评价(?&gt;?&lt;?）\n本人对比6s与p20普通版\n外观：作为一个男生，买了粉色，很喜欢！比极光色还好看我觉得！骚的不行，手感和6s一样宽，所以很舒服！就是长了点，但是手感适合我这种手小的。\n屏幕：比6s大很多，色调并没有那么准，不过屏幕完全没有颗粒感，而且精细度很好，是阴阳屏 ...

# %%
# 剔除多余的部分，得到字典，便于后面处理
import re
result = re.match('.*?\\((.*)\\);', response.text)

# %%
print(result.group(1))
# Out:
# {"productAttr":null,"productCommentSummary":{"goodRateShow":99,"poorRateShow":0,"poorCountStr":"100+","averageScore":5,"generalCountStr":"100+","oneYear":0,"showCount":3800,"showCountStr":"3800+","goodCount":61000,"generalRate":0.99,"generalCount":100,"skuId":6946635,"goodCountStr":"6.1万+","poorRate":0.0020,"afterCount":300,"goodRateStyle":148,"poorCount":100,"skuIds":null,"poorRateStyle":0,"generalRateStyle":2,"commentCountStr":"6.2万+","commentCount":62000,"productId":6946635,"afterCountStr":"300+","defaultGoodCount":46000,"goodRate":0.99,"generalRateShow":1,"defaultGoodCountStr":"4.6万+"},"hotCommentTagStatistics":[{"id":"9255a9406d7c6996","name":"眼前一亮","rid":"9255a9406d7c6996","count":122,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=9255a9406d7c6996^^pid=20001^^sku=6946635^^sversion=1000^^token=4e95d4dbae38e31a"},{"id":"75939b54ad8c3c8c","name":"外观美美哒","rid":"75939b54ad8c3c8c","count":44,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=75939b54ad8c3c8c^^pid=20001^^sku=6946635^^sversion=1000^^token=8aa0129361d128fe"},{"id":"dfb9ca5586caf544","name":"国产粉丝党","rid":"dfb9ca5586caf544","count":28,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=dfb9ca5586caf544^^pid=20001^^sku=6946635^^sversion=1000^^token=405e80c8e9711f56"},{"id":"138066a0d614e743","name":"全能产品","rid":"138066a0d614e743","count":24,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=138066a0d614e743^^pid=20001^^sku=6946635^^sversion=1000^^token=aa7671a914c2336b"},{"id":"3607557658a3dbc1","name":"快快快","rid":"3607557658a3dbc1","count":18,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=3607557658a3dbc1^^pid=20001^^sku=6946635^^sversion=1000^^token=8c8d313ea2172eec"},{"id":"54830c7b549f9402","name":"简直完美","rid":"54830c7b549f9402","count":9,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=54830c7b549f9402^^pid=20001^^sku=6946635^^sversion=1000^^token=becfef9dbd886532"},{"id":"0bacd2244270003d","name":"超高性价比","rid":"0bacd2244270003d","count":7,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=0bacd2244270003d^^pid=20001^^sku=6946635^^sversion=1000^^token=53de92de723c1f88"},{"id":"5c595753b7b31868","name":"堪比单反","rid":"5c595753b7b31868","count":6,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=5c595753b7b31868^^pid=20001^^sku=6946635^^sversion=1000^^token=1cc0828ec0104282"},{"id":"6f45fc31271ea545","name":"而且便宜","rid":"6f45fc31271ea545","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=6f45fc31271ea545^^pid=20001^^sku=6946635^^sversion=1000^^token=eb43301eb406e741"},{"id":"22d498d28602b79f","name":"续航能力强","rid":"22d498d28602b79f","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=22d498d28602b79f^^pid=20001^^sku=6946635^^sversion=1000^^token=1aca49ed749d5be2"},{"id":"bf87168fb66cf160","name":"非常耐用","rid":"bf87168fb66cf160","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=bf87168fb66cf160^^pid=20001^^sku=6946635^^sversion=1000^^token=e9001b2c5d9dd170"},{"id":"8409ae56b10f635b","name":"刚好适合","rid":"8409ae56b10f635b","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=8409ae56b10f635b^^pid=20001^^sku=6946635^^sversion=1000^^token=0406d93dd7a7c37d"},{"id":"e8c1530719ca2fc6","name":"电池续航能力强","rid":"e8c1530719ca2fc6","count":4,"type":4,"canBeFiltered":true,"stand":1,"ckeKeyWordBury":"eid=104^^tagid=e8c1530719ca2fc6^^pid=20001^^sku=6946635^^sversion=1000^^token=f0bee2225ad702ab"}],"jwotestProduct":"99","maxPage":100,"score":0,"soType":5,"imageListCount":500,"vTagStatistics":null,"comments":[{"id":11441149474,"topped":0,"guid":"be7f1d4a-8d68-432c-80c1-dd037d203c2c","content":"京东买了无数次东西，头一次打算好好评价(?&gt;?&lt;?）\n本人对比6s与p20普通版\n外观：作为一个男生，买了粉色，很喜欢！比极光色还好看我觉得！骚的不行，手感和6s一样宽，所以很舒服！就是长了点，但是手感适合我这种手小的。\n屏幕：比6s大很多，色调并没有那么准，不过屏幕完全没有颗粒感，而且精细度很好，是阴阳屏，但是下面黄的很不明显\n没有遇到网上说的缝隙过大 ...

# %%
print(type(result.group(1)))
# Out:
# <class 'str'>

# %%
# 转换为json格式
import json
data = json.loads(result.group(1))

# %%
print(data)
# Out:
# {'productAttr': None, 'productCommentSummary': {'goodRateShow': 99, 'poorRateShow': 0, 'poorCountStr': '100+', 'averageScore': 5, 'generalCountStr': '100+', 'oneYear': 0, 'showCount': 3800, 'showCountStr': '3800+', 'goodCount': 61000, 'generalRate': 0.99, 'generalCount': 100, 'skuId': 6946635, 'goodCountStr': '6.1万+', 'poorRate': 0.002, 'afterCount': 300, 'goodRateStyle': 148, 'poorCount': 100, 'skuIds': None, 'poorRateStyle': 0, 'generalRateStyle': 2, 'commentCountStr': '6.2万+', 'commentCount': 62000, 'productId': 6946635, 'afterCountStr': '300+', 'defaultGoodCount': 46000, 'goodRate': 0.99, 'generalRateShow': 1, 'defaultGoodCountStr': '4.6万+'}, 'hotCommentTagStatistics': [{'id': '9255a9406d7c6996', 'name': '眼前一亮', 'rid': '9255a9406d7c6996', 'count': 122, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=9255a9406d7c6996^^pid=20001^^sku=6946635^^sversion=1000^^token=4e95d4dbae38e31a'}, {'id': '75939b54ad8c3c8c', 'name': '外观美美哒', 'rid': '75939b54ad8c3c8c', 'count': 44, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=75939b54ad8c3c8c^^pid=20001^^sku=6946635^^sversion=1000^^token=8aa0129361d128fe'}, {'id': 'dfb9ca5586caf544', 'name': '国产粉丝党', 'rid': 'dfb9ca5586caf544', 'count': 28, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=dfb9ca5586caf544^^pid=20001^^sku=6946635^^sversion=1000^^token=405e80c8e9711f56'}, {'id': '138066a0d614e743', 'name': '全能产品', 'rid': '138066a0d614e743', 'count': 24, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=138066a0d614e743^^pid=20001^^sku=6946635^^sversion=1000^^token=aa7671a914c2336b'}, {'id': '3607557658a3dbc1', 'name': '快快快', 'rid': '3607557658a3dbc1', 'count': 18, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=3607557658a3dbc1^^pid=20001^^sku=6946635^^sversion=1000^^token=8c8d313ea2172eec'}, {'id': '54830c7b549f9402', 'name': '简直完美', 'rid': '54830c7b549f9402', 'count': 9, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=54830c7b549f9402^^pid=20001^^sku=6946635^^sversion=1000^^token=becfef9dbd886532'}, {'id': '0bacd2244270003d', 'name': '超高性价比', 'rid': '0bacd2244270003d', 'count': 7, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=0bacd2244270003d^^pid=20001^^sku=6946635^^sversion=1000^^token=53de92de723c1f88'}, {'id': '5c595753b7b31868', 'name': '堪比单反', 'rid': '5c595753b7b31868', 'count': 6, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=5c595753b7b31868^^pid=20001^^sku=6946635^^sversion=1000^^token=1cc0828ec0104282'}, {'id': '6f45fc31271ea545', 'name': '而且便宜', 'rid': '6f45fc31271ea545', 'count': 4, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=6f45fc31271ea545^^pid=20001^^sku=6946635^^sversion=1000^^token=eb43301eb406e741'}, {'id': '22d498d28602b79f', 'name': '续航能力强', 'rid': '22d498d28602b79f', 'count': 4, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=22d498d28602b79f^^pid=20001^^sku=6946635^^sversion=1000^^token=1aca49ed749d5be2'}, {'id': 'bf87168fb66cf160', 'name': '非常耐用', 'rid': 'bf87168fb66cf160', 'count': 4, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=bf87168fb66cf160^^pid=20001^^sku=6946635^^sversion=1000^^token=e9001b2c5d9dd170'}, {'id': '8409ae56b10f635b', 'name': '刚好适合', 'rid': '8409ae56b10f635b', 'count': 4, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=8409ae56b10f635b^^pid=20001^^sku=6946635^^sversion=1000^^token=0406d93dd7a7c37d'}, {'id': 'e8c1530719ca2fc6', 'name': '电池续航能力强', 'rid': 'e8c1530719ca2fc6', 'count': 4, 'type': 4, 'canBeFiltered': True, 'stand': 1, 'ckeKeyWordBury': 'eid=104^^tagid=e8c1530719ca2fc6^^pid=20001^^sku=6946635^^sversion=1000^^token=f0bee2225ad702ab'}], 'jwotestProduct': '99', 'maxPage': 100, 'score': 0, 'soType': 5, 'imageListCount': 500, 'vTagStatistics': None, 'commen ...

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['productAttr', 'productCommentSummary', 'hotCommentTagStatistics', 'jwotestProduct', 'maxPage', 'score', 'soType', 'imageListCount', 'vTagStatistics', 'comments'])

# %%
# 得到评论
coms = data.get('comments')

# %%
print(type(coms))
# Out:
# <class 'list'>

# %%
print(len(coms))
# Out:
# 10

# %%
# 遍历输出每个评论的ID和评论内容
for item in coms:
    print(item.get('id'))
    print(item.get('content').strip())
# Out:
# 11441149474
# 京东买了无数次东西，头一次打算好好评价(?&gt;?&lt;?）
# 本人对比6s与p20普通版
# 外观：作为一个男生，买了粉色，很喜欢！比极光色还好看我觉得！骚的不行，手感和6s一样宽，所以很舒服！就是长了点，但是手感适合我这种手小的。
# 屏幕：比6s大很多，色调并没有那么准，不过屏幕完全没有颗粒感，而且精细度很好，是阴阳屏，但是下面黄的很不明显
# 没有遇到网上说的缝隙过大
# 使用：首先，我安卓最开始确实是不习惯 但是现在我觉得算客观评价因为习惯了。
# 系统流畅度，划屏很流畅，但是打字 各种app优化好的没事，不好的会掉帧，很影响体验，这是优化的问题而且字系统图库放大缩小也不是很流畅，没有苹果打字流畅跟手，总感觉慢点，但是应用打开速度很快，手机速度碾压6s。
# 拍照：不说了，碾压，完完全全碾压。。。
# 续航：和我换了大容量电池6s续航差不多，快充很快，但是说真的续航感觉不满意，3400毫安电池不应该这样
# 总体来说，手机还是满意，尤其是外观
# 11398039560
# 运行速度可以，没怎么去拍照。给妈妈买的妈妈说这手机比以前的s7好用。虽然三星s7是以前的。只能说制作工艺在进步也祝福中国企业越来越好。
# 11396248411
# 我还没有过发布会结束马上抢购的经历，华为让我去抢购了&hellip;用了三个苹果&hellip;现在是华为＋苹果了&hellip;太好看了&hellip;太好用了&hellip;太值了&hellip;同时期待老婆的P20 pro
# 11402748152
# 屏幕显示主流很清晰，拍照逆天！面部解锁神速，无卡顿感比水果好。手机握持感很好，颜值高可爱的刘海屏。总之你值得拥有特别是喜爱拍照的花粉们！
# 11399936278
# 很好！第一时间在京东订购！颜值不错！性能好！配置高！相信京东！不错的手机！支持华为！太高兴了！
# 11393656276
# 机器很漂亮，大小合适，手感相当好，P20使用隐藏刘海后，几乎没有色差，看不出来刘海哈！人脸识别是2D的，要求不要太高，不过反应速度挺快的。用惯背后圆指纹了，录这个指纹很不习惯哈。其它待使用&hellip;&hellip;急着发评论就是为了前2000评论得个电源，看我星星眼！
# 11397008278
# 拿到手后是惊喜！对于大屏手机没有好感，之所以预订了5.8寸的P20，是因为手里的锤子M1实在没办法继续用了，想尝试下华为的产品。反正P20支持七天无理由退货。
# 惊喜的是：展现在眼前的5.8寸P20居然跟5.2寸的锤子M1的外框是一模一样大小！！！好感度嗖嗖上涨&hellip;&hellip;
# 继过一天的使用，确定留它下来陪俺过两年了！
# 11405868552
# 拍照那些确实不是吹的！流海可以隐藏！指纹解锁速度快，面部识别解锁速度快！目前没卡！牛皮不是吹的，火车不是推的！看图。要是在送点东西就巴适了！
# 11398387491
# 京东快递值得表扬，速度很快，希望华为p20给我惊喜，等了你很久，苹果专用户转战华为了
# 11410981922
# 手机还可以   但是跟pro比还是差了点   脸部解锁很黑不是很好用   防水不如pro   而且华为是不支持微信指纹的  有点麻烦  但是手机的其他方面还可以  也挺好看
