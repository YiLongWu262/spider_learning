# %%
import requests

BASE_URL = 'http://www.lesmao.me/thread-'
number = 18000
url = BASE_URL + str(number)+ '-1-1.html'
print(url)

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
}
try:
    response = requests.get(url, headers = headers)
    print(response.status_code)
except:
    print('Error')
# Out:
# http://www.lesmao.me/thread-18000-1-1.html
# 200

# %%
#获取mode的名字，方便后面建立文件夹
from pyquery import PyQuery as pq


doc = pq(response.text)

name = doc('h1').text()
print(name)
# Out:
#  YOUMI 尤蜜荟 Vol.068 Modo Yumi-尤美

# %%
#查找页面中model的图片链接
import re
reg = r'<li><img alt=".*?" src="(.*?\.jpg)"'
pattern = re.compile(reg)
image_urls = re.findall(pattern, response.text)
print(image_urls)
# Out:
# ['http://p.tao1o.com/k/1178/T/YOUMI/068/068_001_3yj_3600_5400.jpg', 'http://p.tao1o.com/k/1178/T/YOUMI/068/068_002_89t_3600_5400.jpg', 'http://p.tao1o.com/k/1178/T/YOUMI/068/068_003_j2x_3600_5400.jpg', 'http://p.tao1o.com/k/1178/T/YOUMI/068/068_004_wym_3600_5400.jpg']

# %%
#打印出每个图片的链接
for url in image_urls:
    print(url)
# Out:
# http://p.tao1o.com/k/1178/T/YOUMI/068/068_001_3yj_3600_5400.jpg
# http://p.tao1o.com/k/1178/T/YOUMI/068/068_002_89t_3600_5400.jpg
# http://p.tao1o.com/k/1178/T/YOUMI/068/068_003_j2x_3600_5400.jpg
# http://p.tao1o.com/k/1178/T/YOUMI/068/068_004_wym_3600_5400.jpg

# %%
#下载图片
for url in image_urls:
    name = url.split('/')[-1]
    print(name)
    image = requests.get(url)
    with open(name,'wb') as f:
        f.write(image.content)
# Out:
# 068_001_3yj_3600_5400.jpg
# 068_002_89t_3600_5400.jpg
# 068_003_j2x_3600_5400.jpg
# 068_004_wym_3600_5400.jpg

# %%
#判断相应的文件夹是否存在
import os
os.path.exists()

# %%
import requests
import re
from pyquery import PyQuery as pq
import os


NUMBER = 5
class LeiSi(object):
    '''爬取model图片'''
    
    def __init__(self):
        self.BASE_URL = 'http://www.lesmao.me/thread-'
        self.headers = {
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
        }
        
        
    def get_page(self,url):
        try:
            response = requests.get(url, headers = self.headers)
            print(response.status_code)
            return response.text
        except:
            print('Error')
    
    #解析得到一个人所有图片链接和目录名
    def parser(self,number):
        print('正在解析第{number}位MM'.format(number=number))
        ImageLists = []#一个人的所有图片链接
        for i in range(1,6,1):
            url = self.BASE_URL + str(number)+ '-'+str(i)+'-1.html'
            #print('正在爬取:{url}'.format(url=url))
            text = self.get_page(url)
            #如果是1，则获取文件夹名字
            if i == 1:
                directoryNmae = self.getName(text)
            imageurls = self.getImageUrls(text)
            for item in imageurls:
                ImageLists.append(item)
        print('解析完成')
        return directoryNmae,ImageLists
        
    #获取model名字，作为存储图像的文件夹名字
    def getName(self,text):
        doc = pq(text)
        return doc('h1').text()
    
    #查找页面中model的图片链接
    def getImageUrls(self,text):
        reg = r'<li><img alt=".*?" src="(.*?\.jpg)"'
        pattern = re.compile(reg)
        ImageUrls = re.findall(pattern, text)
        return ImageUrls
    
    #保存图片到文件夹中
    def saveImages(self,directoryName,image_urls):
        print('开始保存:{directoryName}'.format(directoryName=directoryName))
        #如果不存在directoryName文件夹，就创建
        if os.path.exists(directoryName):
            print('已经保存过{directoryName}'.format(directoryName=directoryName))
            return 
        else:
            os.mkdir(directoryName)
            
        for url in image_urls:
            name = url.split('/')[-1]
            print('++正在保存{name}'.format(name=name))
            image = requests.get(url)
            with open(directoryName+'/'+name,'wb') as f:
                f.write(image.content)
        print('保存{directoryName}完成'.format(directoryName=directoryName))

def main():
    app = LeiSi()
    for n in range(17000,19000,1):
        dirname,ImageLists = app.parser(number=n)
        app.saveImages(directoryName=dirname,image_urls=ImageLists)
    
if __name__ == "__main__":
    main()
# Out:
# 正在解析第17000位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: DKGirl DK御女郎 Vol.040 雪千寻和雪千紫模特合集
# 已经保存过 DKGirl DK御女郎 Vol.040 雪千寻和雪千紫模特合集
# 正在解析第17001位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: YOUMI 尤蜜荟 Vol.068 Modo Yumi-尤美
# 已经保存过 YOUMI 尤蜜荟 Vol.068 Modo Yumi-尤美
# 正在解析第17002位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: YOUMI 尤蜜荟 Vol.069 Modo 珍妮花
# 已经保存过 YOUMI 尤蜜荟 Vol.069 Modo 珍妮花
# 正在解析第17003位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: 猫萌榜 MICAT Vol.030 Modo 叶佳颐
# 已经保存过 猫萌榜 MICAT Vol.030 Modo 叶佳颐
# 正在解析第17004位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: TGOD 推女神 Modo 林紫涵
# 已经保存过 TGOD 推女神 Modo 林紫涵
# 正在解析第17005位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: TGOD 推女神 Modo 穆菲菲
# 已经保存过 TGOD 推女神 Modo 穆菲菲
# 正在解析第17006位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: UGirls 爱尤物 No.866 杨乔之
# 已经保存过 UGirls 爱尤物 No.866 杨乔之
# 正在解析第17007位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: UGirls 爱尤物 No.867 Ella
# 已经保存过 UGirls 爱尤物 No.867 Ella
# 正在解析第17008位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: UGirls 爱尤物 No.868 筱慧和赵智妍特辑
# 已经保存过 UGirls 爱尤物 No.868 筱慧和赵智妍特辑
# 正在解析第17009位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: UGirls 尤果写真 No.307 Modo 叶子
# 已经保存过 UGirls 尤果写真 No.307 Modo 叶子
# 正在解析第17010位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: UGirls 尤果写真 No.308 Modo Orange
# 已经保存过 UGirls 尤果写真 No.308 Modo Orange
# 正在解析第17011位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: Goddes 头条女神 No.449 Modo peggy女护士
#   正在保存449_001_gzu_3456_5184.jpg
#   正在保存449_002_ol4_3456_5184.jpg
#   正在保存449_003_mld_3456_5184.jpg
#   正在保存449_004_qhl_3456_5184.jpg
#   正在保存449_005_rg1_3456_5184.jpg
#   正在保存449_006_sad_3456_5184.jpg
#   正在保存449_007_cao_3456_5184.jpg
#   正在保存449_008_odu_3456_5184.jpg
#   正在保存449_009_rhk_3456_5184.jpg
#   正在保存449_010_cl6_5184_3456.jpg
#   正在保存449_011_zno_3456_5184.jpg
#   正在保存449_012_uq0_5184_3456.jpg
#   正在保存449_013_wyg_5184_3456.jpg
#   正在保存449_014_vbb_5184_3456.jpg
#   正在保存449_015_krm_5184_3456.jpg
#   正在保存449_016_8s9_5184_3456.jpg
#   正在保存449_017_1fo_5184_3456.jpg
#   正在保存449_018_apx_5184_3456.jpg
#   正在保存449_019_j4q_5184_3456.jpg
#   正在保存449_020_gdu_3456_5184.jpg
# 保存 Goddes 头条女神 No.449 Modo peggy女护士完成
# 正在解析第17012位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: KeLa 克拉女神 No.219 幂幂光脚去旅行然
#   正在保存219_001_my9_6793_4534.jpg
#   正在保存219_002_tkh_4912_7360.jpg
#   正在保存219_003_36e_4912_7360.jpg
#   正在保存219_004_33f_7360_4912.jpg
#   正在保存219_005_ibt_7360_4912.jpg
#   正在保存219_006_ci1_6646_4352.jpg
#   正在保存219_007_1h6_7360_4912.jpg
#   正在保存219_008_zxy_7360_4912.jpg
#   正在保存219_009_pa0_7360_4912.jpg
#   正在保存219_010_wx3_7360_4912.jpg
#   正在保存219_011_q5d_7360_4912.jpg
#   正在保存219_012_ppm_7360_4912.jpg
#   正在保存219_013_p3l_7360_4912.jpg
#   正在保存219_014_0ya_7360_4912.jpg
#   正在保存219_015_kio_7360_4912.jpg
#   正在保存219_016_5db_4912_7360.jpg
#   正在保存219_017_c4c_6244_4167.jpg
#   正在保存219_018_pzx_4912_7360.jpg
#   正在保存219_019_p58_6968_4650.jpg
#   正在保存219_020_jjj_7360_4912.jpg
# 保存 KeLa 克拉女神 No.219 幂幂光脚去旅行然完成
# 正在解析第17013位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: KeLa 克拉女神 No.220 森丽大秀美背
#   正在保存220_001_zs9_4246_6361.jpg
#   正在保存220_002_jzb_4574_6853.jpg
#   正在保存220_003_wys_6714_4481.jpg
#   正在保存220_004_0h4_7090_4732.jpg
#   正在保存220_005_hwq_4584_6868.jpg
#   正在保存220_006_lqx_6661_4445.jpg
#   正在保存220_007_sfx_4469_6697.jpg
#   正在保存220_008_qtr_4756_7126.jpg
#   正在保存220_009_dd3_4527_6784.jpg
#   正在保存220_010_ijg_7288_4864.jpg
#   正在保存220_011_y21_6962_4646.jpg
#   正在保存220_012_1g3_4905_3273.jpg
#   正在保存220_013_io6_7068_4717.jpg
#   正在保存220_014_05d_7097_4736.jpg
#   正在保存220_015_o6r_7360_4912.jpg
#   正在保存220_016_575_7360_4912.jpg
#   正在保存220_017_dat_7231_4826.jpg
#   正在保存220_018_do4_7360_4912.jpg
#   正在保存220_019_a5s_7360_4912.jpg
#   正在保存220_020_bry_7360_4912.jpg
# 保存 KeLa 克拉女神 No.220 森丽大秀美背完成
# 正在解析第17014位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: FeiLin 嗲囡囡 Vol.112 Modo 晗大大Via
#   正在保存112_001_159_3600_5400.jpg
#   正在保存112_002_xsr_3600_5400.jpg
#   正在保存112_003_8y4_3600_5400.jpg
#   正在保存112_004_7w1_3600_5400.jpg
#   正在保存112_005_ovq_3600_5400.jpg
#   正在保存112_006_45f_5400_3600.jpg
#   正在保存112_007_yt7_3600_5400.jpg
#   正在保存112_008_ibk_5400_3600.jpg
#   正在保存112_009_tuu_5400_3600.jpg
#   正在保存112_010_wyi_5400_3600.jpg
#   正在保存112_011_mza_5400_3600.jpg
#   正在保存112_012_xgw_5400_3601.jpg
#   正在保存112_013_i5o_5400_3600.jpg
#   正在保存112_014_hu7_3600_5400.jpg
#   正在保存112_015_0ns_3600_5400.jpg
#   正在保存112_016_ygf_3600_5400.jpg
#   正在保存112_017_705_3600_5400.jpg
#   正在保存112_018_spk_5400_3600.jpg
#   正在保存112_019_if0_3600_5400.jpg
#   正在保存112_020_cug_3600_5400.jpg
# 保存 FeiLin 嗲囡囡 Vol.112 Modo 晗大大Via完成
# 正在解析第17015位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: HuaYan 花の颜 Vol.049 Modo 芝芝Booty
#   正在保存049_001_0a4_3600_5400.jpg
#   正在保存049_002_qf1_3600_5400.jpg
#   正在保存049_003_i57_3600_5400.jpg
#   正在保存049_004_pfl_3600_5400.jpg
#   正在保存049_005_tux_3600_5400.jpg
#   正在保存049_006_q9n_3600_5400.jpg
#   正在保存049_007_2pb_3600_5400.jpg
#   正在保存049_008_xn2_3600_5400.jpg
#   正在保存049_009_q4w_3600_5400.jpg
#   正在保存049_010_q0l_3600_5400.jpg
#   正在保存049_011_6ej_3600_5400.jpg
#   正在保存049_012_qua_3600_5400.jpg
#   正在保存049_013_hzd_3600_5400.jpg
#   正在保存049_014_599_3600_5400.jpg
#   正在保存049_015_kgi_3600_5400.jpg
#   正在保存049_016_qo4_3600_5400.jpg
#   正在保存049_017_e5w_3600_5400.jpg
#   正在保存049_018_cgh_3600_5400.jpg
#   正在保存049_019_0n0_3600_5400.jpg
#   正在保存049_020_bey_3600_5400.jpg
# 保存 HuaYan 花の颜 Vol.049 Modo 芝芝Booty完成
# 正在解析第17016位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: Tukmo 兔几盟 Vol.105 Modo 球球
#   正在保存105_001_obp_5400_3600.jpg
#   正在保存105_002_gv6_5400_3600.jpg
#   正在保存105_003_xcb_3600_5400.jpg
#   正在保存105_004_yc3_5400_3600.jpg
#   正在保存105_005_dex_3600_5400.jpg
#   正在保存105_006_l2x_3600_5400.jpg
#   正在保存105_007_jrq_3600_5400.jpg
#   正在保存105_008_9q8_3600_5400.jpg
#   正在保存105_009_q30_3600_5400.jpg
#   正在保存105_010_t6w_3600_5400.jpg
#   正在保存105_011_fja_5400_3600.jpg
#   正在保存105_012_jvc_5400_3600.jpg
#   正在保存105_013_fmh_5400_3600.jpg
#   正在保存105_014_uad_3600_5400.jpg
#   正在保存105_015_ojg_5400_3600.jpg
#   正在保存105_016_hf6_3600_5400.jpg
#   正在保存105_017_cch_5399_3600.jpg
#   正在保存105_018_b2g_3600_5400.jpg
#   正在保存105_019_06o_3600_5400.jpg
#   正在保存105_020_t2h_3600_5400.jpg
# 保存 Tukmo 兔几盟 Vol.105 Modo 球球完成
# 正在解析第17017位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: HuaYang 花漾show Vol.008 Modo 李晨晨
#   正在保存008_001_7c1_3607_5400.jpg
#   正在保存008_002_cup_3607_5400.jpg
#   正在保存008_003_uer_3607_5400.jpg
#   正在保存008_004_m4g_3607_5400.jpg
#   正在保存008_005_neg_3607_5400.jpg
#   正在保存008_006_oa4_3607_5400.jpg
#   正在保存008_007_vfg_3607_5400.jpg
#   正在保存008_008_mfb_3607_5400.jpg
#   正在保存008_009_fps_3607_5400.jpg
#   正在保存008_010_c7t_3607_5400.jpg
#   正在保存008_011_27l_3607_5400.jpg
#   正在保存008_012_nvq_3607_5400.jpg
#   正在保存008_013_sag_3607_5400.jpg
#   正在保存008_014_d86_3607_5400.jpg
#   正在保存008_015_9kx_3607_5400.jpg
#   正在保存008_016_etd_3607_5400.jpg
#   正在保存008_017_ci6_3607_5400.jpg
#   正在保存008_018_eh2_3607_5400.jpg
#   正在保存008_019_rtu_3607_5400.jpg
#   正在保存008_020_1qp_3607_5400.jpg
# 保存 HuaYang 花漾show Vol.008 Modo 李晨晨完成
# 正在解析第17018位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: TGOD 推女神 大胸巨乳倪诗茵
#   正在保存2017-10-10_001_38g_2400_3600.jpg
#   正在保存2017-10-10_002_5wf_2400_3600.jpg
#   正在保存2017-10-10_003_wm1_2400_3600.jpg
#   正在保存2017-10-10_004_mxo_2400_3600.jpg
#   正在保存2017-10-10_005_3dp_2400_3600.jpg
#   正在保存2017-10-10_006_i9g_2400_3600.jpg
#   正在保存2017-10-10_007_zuo_2400_3600.jpg
#   正在保存2017-10-10_008_l4m_2400_3600.jpg
#   正在保存2017-10-10_009_ldq_2400_3600.jpg
#   正在保存2017-10-10_010_hlr_2400_3600.jpg
#   正在保存2017-10-10_011_g1s_2400_3600.jpg
#   正在保存2017-10-10_012_adc_2400_3600.jpg
#   正在保存2017-10-10_013_aoo_2400_3600.jpg
#   正在保存2017-10-10_014_dur_2400_3600.jpg
#   正在保存2017-10-10_015_hkc_2400_3600.jpg
#   正在保存2017-10-10_016_l6z_2400_3600.jpg
#   正在保存2017-10-10_017_nou_2400_3600.jpg
#   正在保存2017-10-10_018_q0w_2400_3600.jpg
#   正在保存2017-10-10_019_ygv_2400_3600.jpg
#   正在保存2017-10-10_020_bbk_2400_3600.jpg
# 保存 TGOD 推女神 大胸巨乳倪诗茵完成
# 正在解析第17019位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: TGOD 推女神 Modo 悦爷
#   正在保存2017-10-12_001_xne_2400_3600.jpg
#   正在保存2017-10-12_002_8fn_2400_3600.jpg
#   正在保存2017-10-12_003_7z7_3600_2400.jpg
#   正在保存2017-10-12_004_7vl_2400_3600.jpg
#   正在保存2017-10-12_005_g0t_2400_3600.jpg
#   正在保存2017-10-12_006_ndt_2400_3600.jpg
#   正在保存2017-10-12_007_oep_2400_3600.jpg
#   正在保存2017-10-12_008_yjr_2400_3600.jpg
#   正在保存2017-10-12_009_hy8_2400_3600.jpg
#   正在保存2017-10-12_010_yjp_2400_3600.jpg
#   正在保存2017-10-12_011_npv_2400_3600.jpg
#   正在保存2017-10-12_012_8vw_2400_3600.jpg
#   正在保存2017-10-12_013_tgo_2400_3600.jpg
#   正在保存2017-10-12_014_x53_2400_3600.jpg
#   正在保存2017-10-12_015_m8o_2400_3600.jpg
#   正在保存2017-10-12_016_0vt_2400_3600.jpg
#   正在保存2017-10-12_017_f24_2400_3600.jpg
#   正在保存2017-10-12_018_7qj_2400_3600.jpg
#   正在保存2017-10-12_019_xe8_2400_3600.jpg
#   正在保存2017-10-12_020_566_2400_3600.jpg
# 保存 TGOD 推女神 Modo 悦爷完成
# 正在解析第17020位MM
# 200
# 200
# 200
# 200
# 200
# 解析完成
# 开始保存: XiuRen 秀人 No.825 Modo 艾小青
#   正在保存825_001_47j_3600_5400.jpg
#   正在保存825_002_pd1_3600_5400.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-d6597d084ad7> in <module>()
#      77
#      78 if __name__ == "__main__":
# ---> 79     main()
#
# <ipython-input-73-d6597d084ad7> in main()
#      74     for n in range(17000,19000,1):
#      75         dirname,ImageLists = app.parser(number=n)
# ---> 76         app.saveImages(directoryName=dirname,image_urls=ImageLists)
#      77
#      78 if __name__ == "__main__":
#
# <ipython-input-73-d6597d084ad7> in saveImages(self, directoryName, image_urls)
#      65             name = url.split('/')[-1]
#      66             print('  正在保存{name}'.format(name=name))
# ---> 67             image = requests.get(url)
#      68             with open(directoryName+'/'+name,'wb') as f:
#      69                 f.write(image.content)
#
# D:\app\Anacoda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\app\Anacoda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\app\Anacoda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\app\Anacoda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\app\Anacoda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     355             conn.request_chunked(method, url, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#     359         # Reset the timeout for the recv() on the socket
#
# D:\app\Anacoda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# D:\app\Anacoda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# D:\app\Anacoda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# D:\app\Anacoda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# D:\app\Anacoda3\lib\http\client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connection.py in connect(self)
#     164
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#     168
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# D:\app\Anacoda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:
