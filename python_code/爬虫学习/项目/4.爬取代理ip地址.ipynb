# %% [markdown]
# 代理池
# http://www.xicidaili.com/
# http://www.xicidaili.com/nn/4

# %%
import requests
base_url = 'http://www.xicidaili.com/nn/'
page = 1;
url = base_url + str(page)
print(url)

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
}

try:
    response = requests.get(url, headers = headers)
except:
    print('ERROR')
# Out:
# http://www.xicidaili.com/nn/1

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, "lxml")

# %%
tbody = soup.find('table')
items = tbody.find_all('tr')

# %%
print(len(items))
# Out:
# 101

# %%
print(items)
# Out:
# [<tr>
# <th class="country">国家</th>
# <th>IP地址</th>
# <th>端口</th>
# <th>服务器地址</th>
# <th class="country">是否匿名</th>
# <th>类型</th>
# <th class="country">速度</th>
# <th class="country">连接时间</th>
# <th width="8%">存活时间</th>
# <th width="20%">验证时间</th>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>219.131.174.174</td>
# <td>808</td>
# <td>
# <a href="/2018-04-25/guangdong">广东云浮</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.22秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.044秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>4天</td>
# <td>18-04-29 15:21</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>122.114.31.177</td>
# <td>808</td>
# <td>
# <a href="/2017-11-27/henan">河南郑州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.107秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.021秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>153天</td>
# <td>18-04-29 15:21</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>61.135.217.7</td>
# <td>80</td>
# <td>
# <a href="/2016-05-13/beijing">北京</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.324秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.064秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>716天</td>
# <td>18-04-29 15:21</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.82.176</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.175秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.035秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>23天</td>
# <td>18-04-29 15:21</td>
# </tr>, <tr class="odd">
# <td class="country"></td>
# <td>140.237.115.56</td>
# <td>808</td>
# <td>
#         电信骨干网
#       </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="7.502秒">
# <div class="bar_inner slow" style="width:64%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.5秒">
# <div class="bar_inner medium" style="width:84%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>119.28.142.148</td>
# <td>8888</td>
# <td>
# <a href="/2018-04-27/beijing">北京</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="7.227秒">
# <div class="bar_inner slow" style="width:66%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.445秒">
# <div class="bar_inner medium" style="width:82%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>222.172.113.1</td>
# <td>61202</td>
# <td>
# <a href="/2018-04-27/heilongjiang">黑龙江大庆</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.161秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.032秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>27.209.2.168</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/shandong">山东淄博</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.119秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.023秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>58分钟</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>14.120.182.182</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.336秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.067秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>7小时</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.82.114</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.448秒">
# <div class="bar_inner fast" style="width:92%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.089秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>4小时</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.90.166</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.161秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.032秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.128.33.98</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.355秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.071秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>5分钟</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.86.164</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-05/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.49秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.098秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>23天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.119.161</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-15/anhui">安徽</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="2.659秒">
# <div class="bar_inner medium" style="width:76%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.531秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>13天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.231.253</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.187秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.037秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.119.158</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/anhui">安徽</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="5.7秒">
# <div class="bar_inner slow" style="width:52%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.14秒">
# <div class="bar_inner medium" style="width:80%">
# </div>
# </div>
# </td>
# <td>19天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.64.65</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-09/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.256秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.051秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>19天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.230.159</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-07/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.745秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.149秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>22天</td>
# <td>18-04-29 15:20</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.67.253</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.579秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.115秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>3小时</td>
# <td>18-04-29 15:17</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.82.112</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.223秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.044秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:15</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>125.118.151.6</td>
# <td>808</td>
# <td>
# <a href="/2017-02-28/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.202秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>425天</td>
# <td>18-04-29 15:15</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>115.221.115.42</td>
# <td>8181</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江温州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.208秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.041秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>12小时</td>
# <td>18-04-29 15:15</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.231.248</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-20/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.2秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>9天</td>
# <td>18-04-29 15:15</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>117.36.103.170</td>
# <td>8118</td>
# <td>
# <a href="/2018-01-17/sanxi">陕西西安</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.11秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.022秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>102天</td>
# <td>18-04-29 15:15</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.228.149</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.185秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.037秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>10小时</td>
# <td>18-04-29 15:14</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.227.167</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.242秒">
# <div class="bar_inner fast" style="width:92%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.048秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:14</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.93.103</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-09/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.179秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.035秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>20天</td>
# <td>18-04-29 15:14</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.65.249</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.19秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.038秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>17天</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.116.23</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-06/anhui">安徽</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="2.454秒">
# <div class="bar_inner medium" style="width:75%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.49秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td>23天</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.93.60</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-01/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.218秒">
# <div class="bar_inner fast" style="width:88%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.043秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>28天</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.231.131</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-20/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.175秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.035秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>8天</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>110.85.241.111</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-27/fujian">福建厦门</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.177秒">
# <div class="bar_inner fast" style="width:88%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.035秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>14.118.252.32</td>
# <td>6666</td>
# <td>
# <a href="/2018-04-29/guangdong">广东江门</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.479秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.095秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>29分钟</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>222.76.187.194</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/fujian">福建厦门</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.623秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.124秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>7小时</td>
# <td>18-04-29 15:13</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>222.76.187.51</td>
# <td>8118</td>
# <td>
# <a href="/2018-01-01/fujian">福建厦门</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.233秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.046秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>118天</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.195.139</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-27/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.202秒">
# <div class="bar_inner fast" style="width:85%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>180.160.103.185</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-27/shanghai">上海</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="1.229秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.245秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>2天</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.84.56</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.253秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.05秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>19天</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.65.160.124</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="2.674秒">
# <div class="bar_inner medium" style="width:72%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.534秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td>17分钟</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>117.57.99.36</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/anhui">安徽淮北</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.282秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.056秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>57分钟</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.84.117</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.153秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>4小时</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.66.123</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.19秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.038秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>15小时</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.110.29</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.152秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 15:12</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>114.100.178.83</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-27/anhui">安徽淮南</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.167秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.033秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>117.64.237.122</td>
# <td>18118</td>
# <td>
# <a href="/2018-03-29/anhui">安徽合肥</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.586秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.117秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>30天</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>59.175.53.53</td>
# <td>61202</td>
# <td>
# <a href="/2018-04-29/hubei">湖北武汉</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.11秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.022秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>1分钟</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.86.42</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.55秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.11秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>23天</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>27.209.235.4</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/shandong">山东滨州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.194秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.038秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>1分钟</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.196.136</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-27/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.284秒">
# <div class="bar_inner fast" style="width:88%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.056秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>110.73.35.24</td>
# <td>8123</td>
# <td>
# <a href="/2016-08-01/guangxi">广西防城港</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.373秒">
# <div class="bar_inner fast" style="width:88%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.074秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>635天</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>117.68.194.157</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/anhui">安徽合肥市巢湖</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.164秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.032秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>1分钟</td>
# <td>18-04-29 15:11</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>112.95.32.175</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.169秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.033秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>11小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.196.246</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.284秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.056秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>12小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.78.207</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-04/anhui">安徽芜湖</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="2.378秒">
# <div class="bar_inner medium" style="width:82%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.475秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td>24天</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>27.16.163.92</td>
# <td>3128</td>
# <td>
# <a href="/2018-04-29/hubei">湖北武汉</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.308秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.061秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>5小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>175.171.149.63</td>
# <td>80</td>
# <td>
# <a href="/2018-04-29/liaoning">辽宁大连</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="1.137秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.227秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>3小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>182.108.47.5</td>
# <td>8888</td>
# <td>
# <a href="/2018-04-29/jiangxi">江西</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="7.545秒">
# <div class="bar_inner slow" style="width:67%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="1.509秒">
# <div class="bar_inner medium" style="width:81%">
# </div>
# </div>
# </td>
# <td>12小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>117.82.55.220</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.144秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.028秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>3小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.93.137</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.202秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>3小时</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>121.62.50.166</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-28/hubei">湖北十堰</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.269秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.053秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 15:10</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>182.202.220.23</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-28/liaoning">辽宁丹东</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.138秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.027秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>21小时</td>
# <td>18-04-29 15:09</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>121.234.34.149</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏盐城</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.181秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.036秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>2小时</td>
# <td>18-04-29 15:08</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.196.178</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-26/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="1.002秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.2秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>3天</td>
# <td>18-04-29 15:08</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>124.113.213.117</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-17/anhui">安徽六安</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.256秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.051秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>11天</td>
# <td>18-04-29 15:07</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>119.162.58.224</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/shandong">山东济南</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.151秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 15:07</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.229.6</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.2秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>2小时</td>
# <td>18-04-29 15:05</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>182.202.220.57</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/liaoning">辽宁丹东</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.154秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>11小时</td>
# <td>18-04-29 15:05</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.88.254</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-04/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.21秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.042秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>25天</td>
# <td>18-04-29 15:05</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>112.80.118.148</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏南京</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.124秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.024秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>9小时</td>
# <td>18-04-29 15:05</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>182.202.220.117</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-28/liaoning">辽宁丹东</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.154秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>16小时</td>
# <td>18-04-29 15:05</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.90.189</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-17/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.172秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.034秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>12天</td>
# <td>18-04-29 15:04</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.119.192</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-05/anhui">安徽</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="1.31秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.262秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>24天</td>
# <td>18-04-29 15:04</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>123.56.89.238</td>
# <td>60443</td>
# <td>
# <a href="/2018-04-21/liaoning">辽宁葫芦岛</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="3.22秒">
# <div class="bar_inner medium" style="width:72%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.644秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>8天</td>
# <td>18-04-29 15:03</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.226.160</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-15/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.2秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>14天</td>
# <td>18-04-29 15:03</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.89.245</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.151秒">
# <div class="bar_inner fast" style="width:91%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:03</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.226.144</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-18/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.183秒">
# <div class="bar_inner fast" style="width:85%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.036秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>11天</td>
# <td>18-04-29 15:03</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>114.230.206.8</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏扬州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.13秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.026秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 15:03</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>222.93.241.177</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.328秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.065秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>14小时</td>
# <td>18-04-29 15:02</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>180.118.244.23</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏镇江</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.201秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>17分钟</td>
# <td>18-04-29 15:02</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>113.87.195.189</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.757秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.151秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>16分钟</td>
# <td>18-04-29 15:02</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>111.170.81.96</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/guizhou">贵州贵阳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.153秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.03秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>13小时</td>
# <td>18-04-29 15:01</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.225.224</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.504秒">
# <div class="bar_inner fast" style="width:90%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.1秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>22天</td>
# <td>18-04-29 15:01</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>60.177.230.53</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-23/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.201秒">
# <div class="bar_inner fast" style="width:87%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.04秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>5天</td>
# <td>18-04-29 15:01</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.84.111</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.187秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.037秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>18天</td>
# <td>18-04-29 15:01</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>118.80.212.235</td>
# <td>61202</td>
# <td>
# <a href="/2018-04-29/shanxi">山西阳泉</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.075秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.015秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>1分钟</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.79.139</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-24/anhui">安徽芜湖</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.137秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.027秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>4天</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.4.30.251</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/guangdong">广东广州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.182秒">
# <div class="bar_inner fast" style="width:85%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.036秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.78.24</td>
# <td>8010</td>
# <td>
# <a href="/2017-12-08/anhui">安徽芜湖</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="2.4秒">
# <div class="bar_inner medium" style="width:79%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.48秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td>142天</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.75.187.96</td>
# <td>61202</td>
# <td>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.137秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.027秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>1分钟</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>223.241.118.183</td>
# <td>8010</td>
# <td>
# <a href="/2017-12-26/anhui">安徽</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="2.019秒">
# <div class="bar_inner medium" style="width:72%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.403秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>124天</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.84.29</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.272秒">
# <div class="bar_inner fast" style="width:86%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.054秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.94.22</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.175秒">
# <div class="bar_inner fast" style="width:94%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.035秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>19天</td>
# <td>18-04-29 15:00</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.159.82.252</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-12/zhejiang">浙江杭州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.211秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.042秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td>17天</td>
# <td>18-04-29 14:58</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>218.72.108.79</td>
# <td>18118</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江杭州市富阳</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.156秒">
# <div class="bar_inner fast" style="width:92%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.031秒">
# <div class="bar_inner fast" style="width:97%">
# </div>
# </div>
# </td>
# <td>1小时</td>
# <td>18-04-29 14:58</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>119.186.238.252</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-25/shandong">山东枣庄</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.127秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.025秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>4天</td>
# <td>18-04-29 14:57</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>1.196.135.179</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-28/henan">河南商丘</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.245秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.049秒">
# <div class="bar_inner fast" style="width:96%">
# </div>
# </div>
# </td>
# <td>21小时</td>
# <td>18-04-29 14:57</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>183.136.101.78</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-29/zhejiang">浙江台州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.184秒">
# <div class="bar_inner fast" style="width:85%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.036秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>5小时</td>
# <td>18-04-29 14:56</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.195.157</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-27/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.198秒">
# <div class="bar_inner fast" style="width:93%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.039秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 14:56</td>
# </tr>, <tr class="odd">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>58.249.98.105</td>
# <td>8118</td>
# <td>
# <a href="/2018-04-29/guangdong">广东广州</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTPS</td>
# <td class="country">
# <div class="bar" title="0.198秒">
# <div class="bar_inner fast" style="width:89%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.039秒">
# <div class="bar_inner fast" style="width:98%">
# </div>
# </div>
# </td>
# <td>7小时</td>
# <td>18-04-29 14:56</td>
# </tr>, <tr class="">
# <td class="country"><img alt="Cn" src="http://fs.xicidaili.com/images/flag/cn.png"/></td>
# <td>49.79.194.77</td>
# <td>61234</td>
# <td>
# <a href="/2018-04-28/jiangsu">江苏</a>
# </td>
# <td class="country">高匿</td>
# <td>HTTP</td>
# <td class="country">
# <div class="bar" title="0.208秒">
# <div class="bar_inner fast" style="width:99%">
# </div>
# </div>
# </td>
# <td class="country">
# <div class="bar" title="0.041秒">
# <div class="bar_inner fast" style="width:95%">
# </div>
# </div>
# </td>
# <td>1天</td>
# <td>18-04-29 14:55</td>
# </tr>]

# %%
iplists = []
for item in items:
    if len(item.find_all('td')) != 0:
        ip = item.find_all('td')[1].text
        port = item.find_all('td')[2].text
        #找到地址，
        location = item.find_all('td')[3].a
        #print('ip:{ip} port:{port}'.format(ip = ip,port = port))
        tmp = {'ip':ip,'port':port,'location':location}
        iplists.append(tmp)
# Out:
# <a href="/2018-04-25/guangdong">广东云浮</a>
# <a href="/2017-11-27/henan">河南郑州</a>
# <a href="/2016-05-13/beijing">北京</a>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# None
# <a href="/2018-04-27/beijing">北京</a>
# <a href="/2018-04-27/heilongjiang">黑龙江大庆</a>
# <a href="/2018-04-29/shandong">山东淄博</a>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-05/zhejiang">浙江杭州</a>
# <a href="/2018-04-15/anhui">安徽</a>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# <a href="/2018-04-10/anhui">安徽</a>
# <a href="/2018-04-09/zhejiang">浙江杭州</a>
# <a href="/2018-04-07/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# <a href="/2017-02-28/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江温州</a>
# <a href="/2018-04-20/zhejiang">浙江杭州</a>
# <a href="/2018-01-17/sanxi">陕西西安</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# <a href="/2018-04-09/zhejiang">浙江杭州</a>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# <a href="/2018-04-06/anhui">安徽</a>
# <a href="/2018-04-01/zhejiang">浙江杭州</a>
# <a href="/2018-04-20/zhejiang">浙江杭州</a>
# <a href="/2018-04-27/fujian">福建厦门</a>
# <a href="/2018-04-29/guangdong">广东江门</a>
# <a href="/2018-04-29/fujian">福建厦门</a>
# <a href="/2018-01-01/fujian">福建厦门</a>
# <a href="/2018-04-27/jiangsu">江苏</a>
# <a href="/2018-04-27/shanghai">上海</a>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# <a href="/2018-04-29/anhui">安徽淮北</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-27/anhui">安徽淮南</a>
# <a href="/2018-03-29/anhui">安徽合肥</a>
# <a href="/2018-04-29/hubei">湖北武汉</a>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/shandong">山东滨州</a>
# <a href="/2018-04-27/jiangsu">江苏</a>
# <a href="/2016-08-01/guangxi">广西防城港</a>
# <a href="/2018-04-29/anhui">安徽合肥市巢湖</a>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# <a href="/2018-04-29/jiangsu">江苏</a>
# <a href="/2018-04-04/anhui">安徽芜湖</a>
# <a href="/2018-04-29/hubei">湖北武汉</a>
# <a href="/2018-04-29/liaoning">辽宁大连</a>
# <a href="/2018-04-29/jiangxi">江西</a>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-28/hubei">湖北十堰</a>
# <a href="/2018-04-28/liaoning">辽宁丹东</a>
# <a href="/2018-04-29/jiangsu">江苏盐城</a>
# <a href="/2018-04-26/jiangsu">江苏</a>
# <a href="/2018-04-17/anhui">安徽六安</a>
# <a href="/2018-04-29/shandong">山东济南</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/liaoning">辽宁丹东</a>
# <a href="/2018-04-04/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/jiangsu">江苏南京</a>
# <a href="/2018-04-28/liaoning">辽宁丹东</a>
# <a href="/2018-04-17/zhejiang">浙江杭州</a>
# <a href="/2018-04-05/anhui">安徽</a>
# <a href="/2018-04-21/liaoning">辽宁葫芦岛</a>
# <a href="/2018-04-15/zhejiang">浙江杭州</a>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# <a href="/2018-04-18/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/jiangsu">江苏扬州</a>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# <a href="/2018-04-29/jiangsu">江苏镇江</a>
# <a href="/2018-04-29/guangdong">广东深圳</a>
# <a href="/2018-04-29/guizhou">贵州贵阳</a>
# <a href="/2018-04-06/zhejiang">浙江杭州</a>
# <a href="/2018-04-23/zhejiang">浙江杭州</a>
# <a href="/2018-04-11/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/shanxi">山西阳泉</a>
# <a href="/2018-04-24/anhui">安徽芜湖</a>
# <a href="/2018-04-29/guangdong">广东广州</a>
# <a href="/2017-12-08/anhui">安徽芜湖</a>
# <a href="/2018-04-29/jiangsu">江苏苏州</a>
# <a href="/2017-12-26/anhui">安徽</a>
# <a href="/2018-04-29/zhejiang">浙江杭州</a>
# <a href="/2018-04-10/zhejiang">浙江杭州</a>
# <a href="/2018-04-12/zhejiang">浙江杭州</a>
# <a href="/2018-04-29/zhejiang">浙江杭州市富阳</a>
# <a href="/2018-04-25/shandong">山东枣庄</a>
# <a href="/2018-04-28/henan">河南商丘</a>
# <a href="/2018-04-29/zhejiang">浙江台州</a>
# <a href="/2018-04-27/jiangsu">江苏</a>
# <a href="/2018-04-29/guangdong">广东广州</a>
# <a href="/2018-04-28/jiangsu">江苏</a>

# %%
print(iplists)
# Out:
# [{'ip': '111.197.239.219', 'port': '8118'}, {'ip': '183.159.94.132', 'port': '18118'}, {'ip': '183.159.84.129', 'port': '18118'}, {'ip': '218.72.64.157', 'port': '18118'}, {'ip': '222.76.187.194', 'port': '8118'}, {'ip': '223.241.116.5', 'port': '18118'}, {'ip': '60.177.231.131', 'port': '18118'}, {'ip': '183.159.94.67', 'port': '18118'}, {'ip': '114.225.171.84', 'port': '53128'}, {'ip': '183.159.84.117', 'port': '18118'}, {'ip': '110.85.241.111', 'port': '8118'}, {'ip': '123.56.89.238', 'port': '60443'}, {'ip': '49.79.196.179', 'port': '61234'}, {'ip': '183.159.95.80', 'port': '18118'}, {'ip': '60.177.224.201', 'port': '18118'}, {'ip': '112.239.90.159', 'port': '61234'}, {'ip': '114.215.107.94', 'port': '60443'}, {'ip': '111.170.105.230', 'port': '61234'}, {'ip': '112.80.118.148', 'port': '8118'}, {'ip': '183.159.90.67', 'port': '18118'}, {'ip': '183.159.91.88', 'port': '18118'}, {'ip': '42.7.26.21', 'port': '60443'}, {'ip': '183.159.81.194', 'port': '18118'}, {'ip': '183.159.89.25', 'port': '18118'}, {'ip': '60.177.225.158', 'port': '18118'}, {'ip': '222.89.74.246', 'port': '8010'}, {'ip': '223.241.118.213', 'port': '8010'}, {'ip': '180.121.131.44', 'port': '808'}, {'ip': '114.230.206.8', 'port': '8118'}, {'ip': '110.73.2.199', 'port': '8123'}, {'ip': '121.62.50.166', 'port': '61234'}, {'ip': '49.79.195.225', 'port': '61234'}, {'ip': '49.79.193.44', 'port': '61234'}, {'ip': '182.108.47.5', 'port': '8888'}, {'ip': '49.79.196.178', 'port': '61234'}, {'ip': '124.135.101.91', 'port': '61234'}, {'ip': '183.159.94.22', 'port': '18118'}, {'ip': '182.202.220.8', 'port': '61234'}, {'ip': '183.4.30.251', 'port': '8118'}, {'ip': '183.159.90.205', 'port': '18118'}, {'ip': '119.180.199.63', 'port': '61234'}, {'ip': '119.28.142.148', 'port': '8888'}, {'ip': '183.159.93.60', 'port': '18118'}, {'ip': '61.135.217.7', 'port': '80'}, {'ip': '122.114.31.177', 'port': '808'}, {'ip': '183.159.82.83', 'port': '18118'}, {'ip': '183.159.89.245', 'port': '18118'}, {'ip': '218.72.111.37', 'port': '18118'}, {'ip': '175.171.149.63', 'port': '80'}, {'ip': '183.159.88.97', 'port': '18118'}, {'ip': '221.230.199.116', 'port': '8181'}, {'ip': '183.128.32.66', 'port': '18118'}, {'ip': '183.159.92.198', 'port': '18118'}, {'ip': '60.177.225.110', 'port': '18118'}, {'ip': '223.241.78.84', 'port': '8010'}, {'ip': '113.87.192.89', 'port': '61234'}, {'ip': '223.241.78.249', 'port': '18118'}, {'ip': '182.202.220.55', 'port': '61234'}, {'ip': '27.16.163.92', 'port': '3128'}, {'ip': '223.241.78.149', 'port': '18118'}, {'ip': '121.234.34.149', 'port': '61234'}, {'ip': '183.159.85.157', 'port': '18118'}, {'ip': '27.40.157.124', 'port': '61234'}, {'ip': '27.190.24.158', 'port': '8118'}, {'ip': '183.159.95.57', 'port': '18118'}, {'ip': '115.219.108.204', 'port': '8010'}, {'ip': '183.159.80.84', 'port': '18118'}, {'ip': '223.241.116.154', 'port': '8010'}, {'ip': '112.95.32.175', 'port': '8118'}, {'ip': '110.73.55.208', 'port': '8123'}, {'ip': '125.118.148.184', 'port': '808'}, {'ip': '119.96.75.87', 'port': '61202'}, {'ip': '183.159.94.129', 'port': '18118'}, {'ip': '183.136.101.78', 'port': '61234'}, {'ip': '183.159.88.31', 'port': '18118'}, {'ip': '114.214.162.136', 'port': '8118'}, {'ip': '114.100.178.83', 'port': '61234'}, {'ip': '60.177.230.80', 'port': '18118'}, {'ip': '223.241.78.217', 'port': '18118'}, {'ip': '180.118.242.228', 'port': '61234'}, {'ip': '111.183.230.26', 'port': '61234'}, {'ip': '171.13.83.30', 'port': '61234'}, {'ip': '49.79.196.84', 'port': '61234'}, {'ip': '223.241.78.119', 'port': '18118'}, {'ip': '140.237.115.56', 'port': '808'}, {'ip': '59.173.49.230', 'port': '61202'}, {'ip': '222.142.11.60', 'port': '61202'}, {'ip': '180.160.103.185', 'port': '8118'}, {'ip': '183.159.83.42', 'port': '18118'}, {'ip': '223.241.116.68', 'port': '8010'}, {'ip': '119.162.58.224', 'port': '8118'}, {'ip': '218.72.110.29', 'port': '18118'}, {'ip': '183.159.82.176', 'port': '18118'}, {'ip': '49.79.196.155', 'port': '61234'}, {'ip': '223.241.117.118', 'port': '18118'} ...

# %% [markdown]
# 整理一下代码:

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

class AgentPool(object):
    '''IP代理池'''
    def __init__(self):
        self.MAXPAGE_SIZE = 100 #爬取的页面数量
        self.BASE_URL = 'http://www.xicidaili.com/nn/'#爬取的页面的基地址
        self.headers = {
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
        }
        self.ip_lists = [] #获取到的代理池数据
        
    #获取页面
    def getPage(self,url):
        try:
            response = requests.get(url, headers = self.headers)
            print(response.status_code)
            return response.text
        except:
            print('ERROR')

    #获取数据
    def get_data(self,text):
        soup = BeautifulSoup(text, "lxml")
        tbody = soup.find('table')
        items = tbody.find_all('tr')
        for item in items:
            if len(item.find_all('td')) != 0:
                ip,port = self.getIpPort(item)#获取ip和port
                #print('ip:{ip} port:{port}'.format(ip = ip,port = port))
                tmp = {'ip':ip,'port':port}
                self.ip_lists.append(tmp)#添加到ip列表池中

    #获取ip和port
    def getIpPort(self,item):
        #确保找到ip和port，不是表头
        ip = item.find_all('td')[1].text
        port = item.find_all('td')[2].text
        return ip,port
    
    #保存ip代理池到文件
    def saveData(self):
        with open('./ip_agent.txt', 'a', encoding = 'utf-8') as f:
            for item in self.ip_lists:
                f.write(json.dumps(item, ensure_ascii = False) + '\n')

ip_agent = AgentPool()

for index in range(1,ip_agent.MAXPAGE_SIZE+1,1):
    url = ip_agent.BASE_URL + str(index)
    print(url)
    page = ip_agent.getPage(url)
    ip_agent.get_data(page)
    ip_agent.saveData()
    time.sleep(1)
    print('{index} page successfully'.format(index = index))
# Out:
# http://www.xicidaili.com/nn/1
# 200
# 1 page successfully
# http://www.xicidaili.com/nn/2
# 200
# 2 page successfully
# http://www.xicidaili.com/nn/3
# 200
# 3 page successfully
# http://www.xicidaili.com/nn/4
# 200
# 4 page successfully
# http://www.xicidaili.com/nn/5
# 200
# 5 page successfully
# http://www.xicidaili.com/nn/6
# 200
# 6 page successfully
# http://www.xicidaili.com/nn/7
# 200
# 7 page successfully
# http://www.xicidaili.com/nn/8
# 200
# 8 page successfully
# http://www.xicidaili.com/nn/9
# 200
# 9 page successfully
# http://www.xicidaili.com/nn/10
# 200
# 10 page successfully
# http://www.xicidaili.com/nn/11
# 200
# 11 page successfully
# http://www.xicidaili.com/nn/12
# 200
# 12 page successfully
# http://www.xicidaili.com/nn/13
# 200
# 13 page successfully
# http://www.xicidaili.com/nn/14
# 200
# 14 page successfully
# http://www.xicidaili.com/nn/15
# 200
# 15 page successfully
# http://www.xicidaili.com/nn/16
# 200
# 16 page successfully
# http://www.xicidaili.com/nn/17
# 200
# 17 page successfully
# http://www.xicidaili.com/nn/18
# 200
# 18 page successfully
# http://www.xicidaili.com/nn/19
# 200
# 19 page successfully
# http://www.xicidaili.com/nn/20
# 200
# 20 page successfully
# http://www.xicidaili.com/nn/21
# 200
# 21 page successfully
# http://www.xicidaili.com/nn/22
# 200
# 22 page successfully
# http://www.xicidaili.com/nn/23
# 200
# 23 page successfully
# http://www.xicidaili.com/nn/24
# 200
# 24 page successfully
# http://www.xicidaili.com/nn/25
# 200
# 25 page successfully
# http://www.xicidaili.com/nn/26
# 200
# 26 page successfully
# http://www.xicidaili.com/nn/27
# 200
# 27 page successfully
# http://www.xicidaili.com/nn/28
# 200
# 28 page successfully
# http://www.xicidaili.com/nn/29
# 200
# 29 page successfully
# http://www.xicidaili.com/nn/30
# 200
# 30 page successfully
# http://www.xicidaili.com/nn/31
# 200
# 31 page successfully
# http://www.xicidaili.com/nn/32
# 200
# 32 page successfully
# http://www.xicidaili.com/nn/33
# 200
# 33 page successfully
# http://www.xicidaili.com/nn/34
# 200
# 34 page successfully
# http://www.xicidaili.com/nn/35
# 200
# 35 page successfully
# http://www.xicidaili.com/nn/36
# 200
# 36 page successfully
# http://www.xicidaili.com/nn/37
# 200
# 37 page successfully
# http://www.xicidaili.com/nn/38
# 200
# 38 page successfully
# http://www.xicidaili.com/nn/39
# 200
# 39 page successfully
# http://www.xicidaili.com/nn/40
# 200
# 40 page successfully
# http://www.xicidaili.com/nn/41
# 200
# 41 page successfully
# http://www.xicidaili.com/nn/42
# 200
# 42 page successfully
# http://www.xicidaili.com/nn/43
# 200
# 43 page successfully
# http://www.xicidaili.com/nn/44
# 200
# 44 page successfully
# http://www.xicidaili.com/nn/45
# 200
# 45 page successfully
# http://www.xicidaili.com/nn/46
# 200
# 46 page successfully
# http://www.xicidaili.com/nn/47
# 200
# 47 page successfully
# http://www.xicidaili.com/nn/48
# 200
# 48 page successfully
# http://www.xicidaili.com/nn/49
# 200
# 49 page successfully
# http://www.xicidaili.com/nn/50
# 200
# 50 page successfully
# http://www.xicidaili.com/nn/51
# 200
# 51 page successfully
# http://www.xicidaili.com/nn/52
# 200
# 52 page successfully
# http://www.xicidaili.com/nn/53
# 200
# 53 page successfully
# http://www.xicidaili.com/nn/54
# 200
# 54 page successfully
# http://www.xicidaili.com/nn/55
# 200
# 55 page successfully
# http://www.xicidaili.com/nn/56
# 200
# 56 page successfully
# http://www.xicidaili.com/nn/57
# 200
# 57 page successfully
# http://www.xicidaili.com/nn/58
# 200
# 58 page successfully
# http://www.xicidaili.com/nn/59
# 200
# 59 page successfully
# http://www.xicidaili.com/nn/60
# 200
# 60 page successfully
# http://www.xicidaili.com/nn/61
# 200
# 61 page successfully
# http://www.xicidaili.com/nn/62
# 200
# 62 page successfully
# http://www.xicidaili.com/nn/63
# 200
# 63 page successfully
# http://www.xicidaili.com/nn/64
# 200
# 64 page successfully
# http://www.xicidaili.com/nn/65
# 200
# 65 page successfully
# http://www.xicidaili.com/nn/66
# 200
# 66 page successfully
# http://www.xicidaili.com/nn/67
# 200
# 67 page successfully
# http://www.xicidaili.com/nn/68
# 200
# 68 page successfully
# http://www.xicidaili.com/nn/69
# 200
# 69 page successfully
# http://www.xicidaili.com/nn/70
# 200
# 70 page successfully
# http://www.xicidaili.com/nn/71
# 200
# 71 page successfully
# http://www.xicidaili.com/nn/72
# 200
# 72 page successfully
# http://www.xicidaili.com/nn/73
# 200
# 73 page successfully
# http://www.xicidaili.com/nn/74
# 200
# 74 page successfully
# http://www.xicidaili.com/nn/75
# 200
# 75 page successfully
# http://www.xicidaili.com/nn/76
# 200
# 76 page successfully
# http://www.xicidaili.com/nn/77
# 200
# 77 page successfully
# http://www.xicidaili.com/nn/78
# 200
# 78 page successfully
# http://www.xicidaili.com/nn/79
# 200
# 79 page successfully
# http://www.xicidaili.com/nn/80
# 200
# 80 page successfully
# http://www.xicidaili.com/nn/81
# 200
# 81 page successfully
# http://www.xicidaili.com/nn/82
# 200
# 82 page successfully
# http://www.xicidaili.com/nn/83
# 200
# 83 page successfully
# http://www.xicidaili.com/nn/84
# 200
# 84 page successfully
# http://www.xicidaili.com/nn/85
# 200
# 85 page successfully
# http://www.xicidaili.com/nn/86
# 200
# 86 page successfully
# http://www.xicidaili.com/nn/87
# 200
# 87 page successfully
# http://www.xicidaili.com/nn/88
# 200
# 88 page successfully
# http://www.xicidaili.com/nn/89
# 200
# 89 page successfully
# http://www.xicidaili.com/nn/90
# 200
# 90 page successfully
# http://www.xicidaili.com/nn/91
# 200
# 91 page successfully
# http://www.xicidaili.com/nn/92
# 200
# 92 page successfully
# http://www.xicidaili.com/nn/93
# 200
# 93 page successfully
# http://www.xicidaili.com/nn/94
# 200
# 94 page successfully
# http://www.xicidaili.com/nn/95
# 200
# 95 page successfully
# http://www.xicidaili.com/nn/96
# 200
# 96 page successfully
# http://www.xicidaili.com/nn/97
# 200
# 97 page successfully
# http://www.xicidaili.com/nn/98
# 200
# 98 page successfully
# http://www.xicidaili.com/nn/99
# 200
# 99 page successfully
# http://www.xicidaili.com/nn/100
# 200
# 100 page successfully

# %%
len(ip_agent.ip_lists)
# Out:
# 1000

# %% [markdown]
# 再对代码进行整理一下：

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

class AgentPool(object):
    '''IP代理池'''
    def __init__(self):
        self.MAXPAGE_SIZE = 100 #爬取的页面数量
        self.BASE_URL = 'http://www.xicidaili.com/nn/'#爬取的页面的基地址
        self.headers = {
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
        }
        self.ip_lists = [] #获取到的代理池数据
        
    #获取页面
    def getPage(self,url):
        try:
            response = requests.get(url, headers = self.headers)
            print(response.status_code)
            return response.text
        except:
            print('ERROR')

    #获取数据
    def get_data(self,text):
        soup = BeautifulSoup(text, "lxml")
        tbody = soup.find('table')
        items = tbody.find_all('tr')
        for item in items:
            if len(item.find_all('td')) != 0:
                ip,port = self.getIpPort(item)#获取ip和port
                #print('ip:{ip} port:{port}'.format(ip = ip,port = port))
                tmp = {'ip':ip,'port':port}
                self.ip_lists.append(tmp)#添加到ip列表池中

    #获取ip和port
    def getIpPort(self,item):
        #确保找到ip和port，不是表头
        ip = item.find_all('td')[1].text
        port = item.find_all('td')[2].text
        return ip,port
    
    #保存ip代理池到文件
    def saveData(self):
        with open('./ip_agent.txt', 'a', encoding = 'utf-8') as f:
            for item in self.ip_lists:
                f.write(json.dumps(item, ensure_ascii = False) + '\n')


def main():
    ip_agent = AgentPool()
    for index in range(1,ip_agent.MAXPAGE_SIZE+1,1):
        url = ip_agent.BASE_URL + str(index)
        print(url)
        page = ip_agent.getPage(url)
        ip_agent.get_data(page)
        ip_agent.saveData()
        time.sleep(1)
        print('{index} page successfully'.format(index = index))

main()
# Out:
# http://www.xicidaili.com/nn/1
# 200
# 1 page successfully
# http://www.xicidaili.com/nn/2
# 200
# 2 page successfully
# http://www.xicidaili.com/nn/3
# 200
# 3 page successfully
# http://www.xicidaili.com/nn/4
# 200
# 4 page successfully
# http://www.xicidaili.com/nn/5
# 200
# 5 page successfully
# http://www.xicidaili.com/nn/6
# 200
# 6 page successfully
# http://www.xicidaili.com/nn/7
# 200
# 7 page successfully
# http://www.xicidaili.com/nn/8
# 200
# 8 page successfully
# http://www.xicidaili.com/nn/9
# 200
# 9 page successfully
# http://www.xicidaili.com/nn/10
# 200
# 10 page successfully
# http://www.xicidaili.com/nn/11
# 200
# 11 page successfully
# http://www.xicidaili.com/nn/12
# 200
# 12 page successfully
# http://www.xicidaili.com/nn/13
# 200
# 13 page successfully
# http://www.xicidaili.com/nn/14
# 200
# 14 page successfully
# http://www.xicidaili.com/nn/15
# 200
# 15 page successfully
# http://www.xicidaili.com/nn/16
# 200
# 16 page successfully
# http://www.xicidaili.com/nn/17
# 200
# 17 page successfully
# http://www.xicidaili.com/nn/18
# 200
# 18 page successfully
# http://www.xicidaili.com/nn/19
# 200
# 19 page successfully
# http://www.xicidaili.com/nn/20
# 200
# 20 page successfully
# http://www.xicidaili.com/nn/21
# 200
# 21 page successfully
# http://www.xicidaili.com/nn/22
# 200
# 22 page successfully
# http://www.xicidaili.com/nn/23
# 200
# 23 page successfully
# http://www.xicidaili.com/nn/24
# 200
# 24 page successfully
# http://www.xicidaili.com/nn/25
# 200
# 25 page successfully
# http://www.xicidaili.com/nn/26
# 200
# 26 page successfully
# http://www.xicidaili.com/nn/27
# 200
# 27 page successfully
# http://www.xicidaili.com/nn/28
# 200
# 28 page successfully
# http://www.xicidaili.com/nn/29
# 200
# 29 page successfully
# http://www.xicidaili.com/nn/30
# 200
# 30 page successfully
# http://www.xicidaili.com/nn/31
# 200
# 31 page successfully
# http://www.xicidaili.com/nn/32
# 200
# 32 page successfully
# http://www.xicidaili.com/nn/33
# 200
# 33 page successfully
# http://www.xicidaili.com/nn/34
# 200
# 34 page successfully
# http://www.xicidaili.com/nn/35
# 200
# 35 page successfully
# http://www.xicidaili.com/nn/36
# 200
# 36 page successfully
# http://www.xicidaili.com/nn/37
# 200
# 37 page successfully
# http://www.xicidaili.com/nn/38
# 200
# 38 page successfully
# http://www.xicidaili.com/nn/39
# 200
# 39 page successfully
# http://www.xicidaili.com/nn/40
# 200
# 40 page successfully
# http://www.xicidaili.com/nn/41
# 200
# 41 page successfully
# http://www.xicidaili.com/nn/42
# 200
# 42 page successfully
# http://www.xicidaili.com/nn/43
# 200
# 43 page successfully
# http://www.xicidaili.com/nn/44
# 200
# 44 page successfully
# http://www.xicidaili.com/nn/45
# 200
# 45 page successfully
# http://www.xicidaili.com/nn/46
# 200
# 46 page successfully
# http://www.xicidaili.com/nn/47
# 200
# 47 page successfully
# http://www.xicidaili.com/nn/48
# 200
# 48 page successfully
# http://www.xicidaili.com/nn/49
# 200
# 49 page successfully
# http://www.xicidaili.com/nn/50
# 200
# 50 page successfully
# http://www.xicidaili.com/nn/51
# 200
# 51 page successfully
# http://www.xicidaili.com/nn/52
# 200
# 52 page successfully
# http://www.xicidaili.com/nn/53
# 200
# 53 page successfully
# http://www.xicidaili.com/nn/54
# 200
# 54 page successfully
# http://www.xicidaili.com/nn/55
# 200
# 55 page successfully
# http://www.xicidaili.com/nn/56
# 200
# 56 page successfully
# http://www.xicidaili.com/nn/57
# 200
# 57 page successfully
# http://www.xicidaili.com/nn/58
# 200
# 58 page successfully
# http://www.xicidaili.com/nn/59
# 200
# 59 page successfully
# http://www.xicidaili.com/nn/60
# 200
# 60 page successfully
# http://www.xicidaili.com/nn/61
# 200
# 61 page successfully
# http://www.xicidaili.com/nn/62
# 200
# 62 page successfully
# http://www.xicidaili.com/nn/63
# 200
# 63 page successfully
# http://www.xicidaili.com/nn/64
# 200
# 64 page successfully
# http://www.xicidaili.com/nn/65
# 200
# 65 page successfully
# http://www.xicidaili.com/nn/66
# 200
# 66 page successfully
# http://www.xicidaili.com/nn/67
# 200
# 67 page successfully
# http://www.xicidaili.com/nn/68
# 200
# 68 page successfully
# http://www.xicidaili.com/nn/69
# 200
# 69 page successfully
# http://www.xicidaili.com/nn/70
# 200
# 70 page successfully
# http://www.xicidaili.com/nn/71
# 200
# 71 page successfully
# http://www.xicidaili.com/nn/72
# 200
# 72 page successfully
# http://www.xicidaili.com/nn/73
# 200
# 73 page successfully
# http://www.xicidaili.com/nn/74
# 200
# 74 page successfully
# http://www.xicidaili.com/nn/75
# 200
# 75 page successfully
# http://www.xicidaili.com/nn/76
# 200
# 76 page successfully
# http://www.xicidaili.com/nn/77
# 200
# 77 page successfully
# http://www.xicidaili.com/nn/78
# 200
# 78 page successfully
# http://www.xicidaili.com/nn/79
# 200
# 79 page successfully
# http://www.xicidaili.com/nn/80
# 200
# 80 page successfully
# http://www.xicidaili.com/nn/81
# 200
# 81 page successfully
# http://www.xicidaili.com/nn/82
# 200
# 82 page successfully
# http://www.xicidaili.com/nn/83
# 200
# 83 page successfully
# http://www.xicidaili.com/nn/84
# 200
# 84 page successfully
# http://www.xicidaili.com/nn/85
# 200
# 85 page successfully
# http://www.xicidaili.com/nn/86
# 200
# 86 page successfully
# http://www.xicidaili.com/nn/87
# 200
# 87 page successfully
# http://www.xicidaili.com/nn/88
# 200
# 88 page successfully
# http://www.xicidaili.com/nn/89
# 200
# 89 page successfully
# http://www.xicidaili.com/nn/90
# 200
# 90 page successfully
# http://www.xicidaili.com/nn/91
# 200
# 91 page successfully
# http://www.xicidaili.com/nn/92
# 200
# 92 page successfully
# http://www.xicidaili.com/nn/93
# 200
# 93 page successfully
# http://www.xicidaili.com/nn/94
# 200
# 94 page successfully
# http://www.xicidaili.com/nn/95
# 200
# 95 page successfully
# http://www.xicidaili.com/nn/96
# 200
# 96 page successfully
# http://www.xicidaili.com/nn/97
# 200
# 97 page successfully
# http://www.xicidaili.com/nn/98
# 200
# 98 page successfully
# http://www.xicidaili.com/nn/99
# 200
# 99 page successfully
# http://www.xicidaili.com/nn/100
# 200
# 100 page successfully

# %% [markdown]
# 对于爬取的代理ip，我们做个简单的测试

# %%
import requests

ip = '122.138.52.123'
port = '8010'
host = ip +  ':' + port
print(host)

url = 'https://www.baidu.com/'

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
}

proxies = {
  'http': 'https://' + host,
  'https': 'http://' + host,
}

print(proxies)

response = requests.get(url, headers = headers, proxies = proxies)
print(response.status_code)
# Out:
# 223.241.118.64:8010
# {'http': 'https://223.241.118.64:8010', 'https': 'http://223.241.118.64:8010'}
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\app\Anacoda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# D:\app\Anacoda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# D:\app\Anacoda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\app\Anacoda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594             if is_new_proxy_conn:
# --> 595                 self._prepare_proxy(conn)
#     596
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     815
# --> 816         conn.connect()
#     817
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000000000829DF98>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\app\Anacoda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# D:\app\Anacoda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# D:\app\Anacoda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.baidu.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000829DF98>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',)))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-7-59820924d68b> in <module>()
#      19 print(proxies)
#      20
# ---> 21 response = requests.get(url, headers = headers, proxies = proxies)
#      22 print(response.status_code)
#
# D:\app\Anacoda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\app\Anacoda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\app\Anacoda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\app\Anacoda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\app\Anacoda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     500
#     501             if isinstance(e.reason, _ProxyError):
# --> 502                 raise ProxyError(e, request=request)
#     503
#     504             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='www.baidu.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000829DF98>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',)))
